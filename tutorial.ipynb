# %%
from wakeflow import WakeflowModel
# Out:
# WARNING: mpl_scatter_density is not present
# WARNING: progressbar is not present
# You may safely ignore these warnings.

# %%
model = WakeflowModel()
# Out:
# Model initialised.

# %%
model.run(overwrite=True)
# Out:
# * Performing sanity checks on model parameters:
# M_thermal = 0.698 M_Jup
# M_planet  = 0.143 M_th
# Parameters Ok - continuing
# Overwriting previous results
#
# * Creating 0.1 Mj model:
# Generating unperturbed background disk
# Extracting linear perturbations nearby planet
# Propagating outer wake... finished in 41.03 s
# Propagating inner wake... finished in 44.97 s
# * Mapping to physical coords: 100%|██████████| 400/400 [00:28<00:00, 13.94it/s]
# * Displaying results:
# * Saving results:
# Perturbations saved to default_parent_dir/default_results_dir/0.1Mj
# Total         saved to default_parent_dir/default_results_dir/0.1Mj
#
# * Done!
